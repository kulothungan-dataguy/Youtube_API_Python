# %% [markdown]
# <a href="https://colab.research.google.com/github/kulothungan-dataguy/Youtube_API_Python/blob/main/API_YOUTUBE_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import Libraries
import requests
import pandas as pd
import time
from googleapiclient.discovery import build

# %%
#Keys
# How to get API Key for youtube : https://www.slickremix.com/docs/get-api-key-for-youtube/
API_KEY = "XXXX"

# How to get CHANNEL_ID for your youtube channel : https://support.google.com/youtube/answer/3250431?hl=en
CHANNEL_ID = "UC8EqL37DJOg_SYEjNoCVB3g"

# %% [markdown]
# I tried this before and it didnt work
#
# pageToken = ""
#
# url = "GET https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"@channelid="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken
#
# response = requests.get(url).json()

# %%
 #reading our output
 youtube = build('youtube', 'v3', developerKey=API_KEY)

 request = youtube.channels().list(part = 'snippet',id = CHANNEL_ID,maxResults=1000,pageToken="")

 response = request.execute()

 response['items'][0]
# Out:
# {'etag': 'EAEhfl8KOMluQ2A15-Sbm3ibKzw',
#  'id': 'UC8EqL37DJOg_SYEjNoCVB3g',
#  'kind': 'youtube#channel',
#  'snippet': {'description': 'An insane channel controlled by a cyber droid....;)',
#   'localized': {'description': 'An insane channel controlled by a cyber droid....;)',
#    'title': 'Thinketron'},
#   'publishedAt': '2017-02-16T19:00:22Z',
#   'thumbnails': {'default': {'height': 88,
#     'url': 'https://yt3.ggpht.com/ytc/AKedOLRPpW_hj0h-dmXXZhDRvdUiGKxDviZ3BXErj2YM=s88-c-k-c0x00ffffff-no-rj',
#     'width': 88},
#    'high': {'height': 800,
#     'url': 'https://yt3.ggpht.com/ytc/AKedOLRPpW_hj0h-dmXXZhDRvdUiGKxDviZ3BXErj2YM=s800-c-k-c0x00ffffff-no-rj',
#     'width': 800},
#    'medium': {'height': 240,
#     'url': 'https://yt3.ggpht.com/ytc/AKedOLRPpW_hj0h-dmXXZhDRvdUiGKxDviZ3BXErj2YM=s240-c-k-c0x00ffffff-no-rj',
#     'width': 240}},
#   'title': 'Thinketron'}}

# %%
#verifying our output
request = youtube.search().list(part="snippet",channelId="UC8EqL37DJOg_SYEjNoCVB3g",maxResults=1000,pageToken="")
response = request.execute()
response
# Out:
# {'etag': 'hMpgtbfdX2m-q7g7TxoCrcyuZBk',
#  'items': [{'etag': 'KfRUNU3zFyT6BCcLcdIwgj10hGE',
#    'id': {'kind': 'youtube#video', 'videoId': 'Rf6czH7rh_E'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hello viewers...this video shows the step by step procedure of creating LabVIEW program on sequential ON and OFF of three ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-02-16T19:15:46Z',
#     'publishedAt': '2017-02-16T19:15:46Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Rf6czH7rh_E/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Rf6czH7rh_E/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Rf6czH7rh_E/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Sequential blinking of LED&#39;s - LabView'}},
#   {'etag': 'JYg_VTEOSRj1zqVqE-HP_HZBQj0',
#    'id': {'kind': 'youtube#video', 'videoId': 'UyPU1XT-J5w'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hey ppl....so this video is about how to create a basic arithmetic calculator( + , - , * , / ) using labview.....hope it helps...:) TALK WITH ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-14T20:56:35Z',
#     'publishedAt': '2017-04-14T20:56:35Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/UyPU1XT-J5w/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/UyPU1XT-J5w/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/UyPU1XT-J5w/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Basic calculator using Labview'}},
#   {'etag': '5p5L9F34m225g9QBJCfV-k90aic',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLjntR_ayKT2j3062lKGFB_hHQyW4iwNVE'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': '',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-23T06:31:58Z',
#     'publishedAt': '2017-04-23T06:31:58Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/JeYSt43KVtQ/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/JeYSt43KVtQ/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/JeYSt43KVtQ/mqdefault.jpg',
#       'width': 320}},
#     'title': 'PTC Creo / PRO-E'}},
#   {'etag': 'av5sNnxg2gAMbDY6p8jmJWQfhyo',
#    'id': {'kind': 'youtube#video', 'videoId': 'bAVc2KcTHXc'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hi Guys...this video is on how to implement hyperlink using LabVIEW....Here I have created two hyperlinks for desktop folder and ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-02-24T12:33:14Z',
#     'publishedAt': '2017-02-24T12:33:14Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/bAVc2KcTHXc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/bAVc2KcTHXc/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/bAVc2KcTHXc/mqdefault.jpg',
#       'width': 320}},
#     'title': 'HyperLink using LabVIEW'}},
#   {'etag': '9hSkTuPc-rMTaNdx8q8ouuKPzik',
#    'id': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'An insane channel controlled by a cyber droid....;)',
#     'liveBroadcastContent': 'upcoming',
#     'publishTime': '2017-02-16T19:00:22Z',
#     'publishedAt': '2017-02-16T19:00:22Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRPpW_hj0h-dmXXZhDRvdUiGKxDviZ3BXErj2YM=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRPpW_hj0h-dmXXZhDRvdUiGKxDviZ3BXErj2YM=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRPpW_hj0h-dmXXZhDRvdUiGKxDviZ3BXErj2YM=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Thinketron'}},
#   {'etag': 'SHXf2Murf0rM-eXODrmKiHK0Kdk',
#    'id': {'kind': 'youtube#video', 'videoId': 'BL6xo9JNOhg'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'This video is on how to write data onto a empty spreadsheet and how to append data onto a existing spreadsheet using LabVIEW ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-02-21T04:10:52Z',
#     'publishedAt': '2017-02-21T04:10:52Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/BL6xo9JNOhg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/BL6xo9JNOhg/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/BL6xo9JNOhg/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Writing/Appending data onto a spreadsheet using Labview'}},
#   {'etag': '1TuPXJ8u5AFg3UJ5eCrrD7Ea6zY',
#    'id': {'kind': 'youtube#video', 'videoId': 'dLm44iZJXSc'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'This video is on seven segment display using labview......it displays numbers from 0 to 9 in a time sequence....',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-03-13T07:19:01Z',
#     'publishedAt': '2017-03-13T07:19:01Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/dLm44iZJXSc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/dLm44iZJXSc/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/dLm44iZJXSc/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Seven Segment using Labview'}},
#   {'etag': 'nJvdJ75CFpYyytZLEFk7wqARtUA',
#    'id': {'kind': 'youtube#video', 'videoId': 'GVrL76HZTZ0'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hi there.......This video shows the steps to create TAPER PIN using PTC creo / Proengineer....Taper pin is a part of knuckle ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-26T14:07:33Z',
#     'publishedAt': '2017-04-26T14:07:33Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/GVrL76HZTZ0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/GVrL76HZTZ0/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/GVrL76HZTZ0/mqdefault.jpg',
#       'width': 320}},
#     'title': 'KNUCKLE JOINT - Creation of TAPER PIN using PTC creo / PRO-E'}},
#   {'etag': '_ch62WQEShCPnNkHg0zOUf4mq1w',
#    'id': {'kind': 'youtube#video', 'videoId': 'jvkwXIVrk_Q'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hi there..........This video shows us how to create knuckle pin using ptc creo / proengineer.....knuckle joint is a part of knuckle ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-25T06:26:46Z',
#     'publishedAt': '2017-04-25T06:26:46Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/jvkwXIVrk_Q/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/jvkwXIVrk_Q/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/jvkwXIVrk_Q/mqdefault.jpg',
#       'width': 320}},
#     'title': 'KNUCKLE JOINT- Creation of KNUCKLE PIN using PTC Creo / PRO-E'}},
#   {'etag': '_3fWFDYm6xaeBLhnYL0MIKi7_HI',
#    'id': {'kind': 'youtube#video', 'videoId': 'NQg2gVq8W8M'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'assembly of all sub parts...:)',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-26T15:08:25Z',
#     'publishedAt': '2017-04-26T15:08:25Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/NQg2gVq8W8M/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/NQg2gVq8W8M/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/NQg2gVq8W8M/mqdefault.jpg',
#       'width': 320}},
#     'title': 'KNUCKLE JOINT-Assembly of all sub parts'}},
#   {'etag': 'wcrHlv6Br8gJzawYmUkAh3TBwrQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'dSWv6FM4AVM'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hi everyone.....This video shows us how to create EYEEND using PTC Creo / Proengineer.....EYEEND is a part of KNUCKLE ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-25T00:57:08Z',
#     'publishedAt': '2017-04-25T00:57:08Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/dSWv6FM4AVM/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/dSWv6FM4AVM/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/dSWv6FM4AVM/mqdefault.jpg',
#       'width': 320}},
#     'title': 'KNUCKLE JOINT - Creation of EYEEND using PTC Creo / PRO-E'}},
#   {'etag': 'XmAKiCfD9mvaOCWQfXGZIUYFYNo',
#    'id': {'kind': 'youtube#video', 'videoId': 'Bea3A2SGmr8'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hi there....this video shows us the steps to create collar using PTC creo / Proengineer.....COLLAR is a part of knuckle joint.....hope ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-26T14:02:26Z',
#     'publishedAt': '2017-04-26T14:02:26Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Bea3A2SGmr8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Bea3A2SGmr8/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Bea3A2SGmr8/mqdefault.jpg',
#       'width': 320}},
#     'title': 'KNUCKLE JOINT-Creation of COLLAR using PTC creo / PRO-E'}},
#   {'etag': 'cHVMVb5N5limNkGNTUUtwwJ7-r8',
#    'id': {'kind': 'youtube#video', 'videoId': 'JeYSt43KVtQ'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC8EqL37DJOg_SYEjNoCVB3g',
#     'channelTitle': 'Thinketron',
#     'description': 'Hi everyone....This video shows how to create a fork end using PTC Creo / PRO-E....Fork end is a part of Knuckle Joint....Hope it ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-23T08:17:24Z',
#     'publishedAt': '2017-04-23T08:17:24Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/JeYSt43KVtQ/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/JeYSt43KVtQ/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/JeYSt43KVtQ/mqdefault.jpg',
#       'width': 320}},
#     'title': 'KNUCKLE JOINT - PART 1 Creation of FORK END using PTC CREO/PRO-E'}}],
#  'kind': 'youtube#searchListResponse',
#  'pageInfo': {'resultsPerPage': 13, 'totalResults': 13},
#  'regionCode': 'TW'}

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"])
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, upload_date, view_count, like_count, comment_count]
# Index: []

# %%
request2 = youtube.videos().list(part="statistics",id='dLm44iZJXSc')
response2 = request2.execute()
response2
# Out:
# {'etag': '3cUIrMvOH-Q98A5lQrXDOQEY-uY',
#  'items': [{'etag': 'O5qqkdZ9vZDZRkXWLlN-tQM9Z64',
#    'id': 'dLm44iZJXSc',
#    'kind': 'youtube#video',
#    'statistics': {'commentCount': '2',
#     'favoriteCount': '0',
#     'likeCount': '59',
#     'viewCount': '12203'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
#loop to add to df
for video in response['items']:
  if video['id']['kind'] == "youtube#video":
    video_id = video['id']['videoId']
    video_title = video['snippet']['title']
    video_title = str(video_title).replace("&amp;","")
    upload_date = video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]
    request2 = youtube.videos().list(part="statistics",id=video_id)
    response2 = request2.execute()
    view_count = response2['items'][0]['statistics']['viewCount']
    try:
      like_count = response2['items'][0]['statistics']['likeCount']
    except:
      like_count = 0
    #dislike_count = response2['items'][0]['statistics']['dislikeCount']
    comment_count = response2['items'][0]['statistics']['commentCount']
    df = df.append({'video_id':video_id,'video_title':video_title,"upload_date":upload_date,"view_count":view_count,"like_count":like_count,"comment_count":comment_count},ignore_index=True)

# %%
#Converting to CSV
df.to_csv('youtube_vids_2nd_pull.csv')
